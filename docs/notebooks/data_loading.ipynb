# %% [markdown]
# # Data Loading

# %%
import os
import sys
import logging
import scgenome.db.search

LOGGING_FORMAT = "%(asctime)s - %(levelname)s - %(message)s"
logging.basicConfig(format=LOGGING_FORMAT, stream=sys.stderr, level=logging.INFO)

local_cache_directory = os.environ['TANTALUS_CACHE_DIR']

library_id = 'A96157C'

analysis = scgenome.db.search.search_hmmcopy_analysis(
    library_id,
    aligner_name='BWA_MEM_0_7_6A',
)

print(analysis['jira_ticket'])
# Out:
# 2019-11-04 18:41:04,237 - INFO - searching for hmmcopy data for A96157C
# 2019-11-04 18:41:06,287 - INFO - found results from jira ticket SC-3041
# SC-3041

# %%
import scgenome.db.qc

hmmcopy_tickets = [
    'SC-1935',
    'SC-1936',
    'SC-1937',
]

sample_ids = [
    'SA1090',
    'SA921',
    'SA922',
]

results_tables = scgenome.db.qc.get_qc_data(
    hmmcopy_tickets,
    local_cache_directory,
    sample_ids=sample_ids,
    do_caching=False,
)

cn_data, metrics_data = (
    results_tables['hmmcopy_reads'],
    results_tables['annotation_metrics'],
)

print(cn_data.head())
# Out:
# /Users/mcphera1/Projects/scgenome/scgenome/utils.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype('category')
# /Users/mcphera1/Projects/scgenome/scgenome/utils.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].cat.set_categories(col_categories[col])
#   chr    start      end  reads        gc      copy  state  \
# 0   1        1   500000     13 -1.000000       NaN      6
# 1   1   500001  1000000    442 -1.000000       NaN      6
# 2   1  1000001  1500000    461  0.598332  6.672340      6
# 3   1  1500001  2000000    478  0.539498  5.211916      6
# 4   1  2000001  2500000    594  0.594508  8.384862      6
#
#                  cell_id sample_id library_id
# 0  SA922-A90554B-R34-C70     SA922    A90554B
# 1  SA922-A90554B-R34-C70     SA922    A90554B
# 2  SA922-A90554B-R34-C70     SA922    A90554B
# 3  SA922-A90554B-R34-C70     SA922    A90554B
# 4  SA922-A90554B-R34-C70     SA922    A90554B

# %%
import dbclients.tantalus
import datamanagement.transfer_files

ticket_id = 'SC-1939'

local_cache_directory = os.environ['TANTALUS_CACHE_DIR']

tantalus_api = dbclients.tantalus.TantalusApi()

ticket_results = tantalus_api.list('results', analysis__jira_ticket=ticket_id)

for results in ticket_results:
    filepaths = datamanagement.transfer_files.cache_dataset(
        tantalus_api,
        results['id'],
        'resultsdataset',
        'singlecellresults',
        local_cache_directory,
    )
# Out:
# 2019-11-04 18:42:41,178 - INFO - 702a37f8-c0d2-46e5-9177-91ece06a7afc - TokenRequest:Getting token with client credentials.
# 2019-11-04 18:42:41,600 - INFO - 702a37f8-c0d2-46e5-9177-91ece06a7afc - OAuth2Client:Get Token Server returned this correlation_id: 702a37f8-c0d2-46e5-9177-91ece06a7afc
# 2019-11-04 18:42:48,665 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_annotations.h5 to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,094 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_annotations.h5 that matches existing file
# 2019-11-04 18:42:49,094 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_counts.h5 to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,160 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_counts.h5 that matches existing file
# 2019-11-04 18:42:49,160 - INFO - starting caching SC-1939/results/SA921_A90554A_museq.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,244 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_museq.vcf.gz that matches existing file
# 2019-11-04 18:42:49,245 - INFO - starting caching SC-1939/results/SA921_A90554A_museq.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,315 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_museq.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:49,316 - INFO - starting caching SC-1939/results/SA921_A90554A_museq.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,451 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_museq.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:49,452 - INFO - starting caching SC-1939/results/SA921_A90554A_strelka_snv.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,517 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_strelka_snv.vcf.gz that matches existing file
# 2019-11-04 18:42:49,518 - INFO - starting caching SC-1939/results/SA921_A90554A_strelka_snv.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,583 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_strelka_snv.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:49,584 - INFO - starting caching SC-1939/results/SA921_A90554A_strelka_snv.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,649 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_strelka_snv.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:49,650 - INFO - starting caching SC-1939/results/SA921_A90554A_strelka_indel.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,717 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_strelka_indel.vcf.gz that matches existing file
# 2019-11-04 18:42:49,718 - INFO - starting caching SC-1939/results/SA921_A90554A_strelka_indel.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,786 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_strelka_indel.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:49,787 - INFO - starting caching SC-1939/results/SA921_A90554A_strelka_indel.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,855 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_strelka_indel.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:49,856 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_annotations.h5 to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,923 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_annotations.h5 that matches existing file
# 2019-11-04 18:42:49,923 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_counts.h5 to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:49,991 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_counts.h5 that matches existing file
# 2019-11-04 18:42:49,992 - INFO - starting caching SC-1939/results/SA922_A90554B_museq.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,061 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_museq.vcf.gz that matches existing file
# 2019-11-04 18:42:50,062 - INFO - starting caching SC-1939/results/SA922_A90554B_museq.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,131 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_museq.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:50,132 - INFO - starting caching SC-1939/results/SA922_A90554B_museq.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,240 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_museq.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:50,240 - INFO - starting caching SC-1939/results/SA922_A90554B_strelka_snv.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,308 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_strelka_snv.vcf.gz that matches existing file
# 2019-11-04 18:42:50,308 - INFO - starting caching SC-1939/results/SA922_A90554B_strelka_snv.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,375 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_strelka_snv.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:50,376 - INFO - starting caching SC-1939/results/SA922_A90554B_strelka_snv.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,444 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_strelka_snv.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:50,444 - INFO - starting caching SC-1939/results/SA922_A90554B_strelka_indel.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,510 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_strelka_indel.vcf.gz that matches existing file
# 2019-11-04 18:42:50,511 - INFO - starting caching SC-1939/results/SA922_A90554B_strelka_indel.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,579 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_strelka_indel.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:50,580 - INFO - starting caching SC-1939/results/SA922_A90554B_strelka_indel.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,644 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_strelka_indel.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:50,645 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_annotations.h5 to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,712 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_annotations.h5 that matches existing file
# 2019-11-04 18:42:50,713 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_counts.h5 to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,783 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_counts.h5 that matches existing file
# 2019-11-04 18:42:50,783 - INFO - starting caching SC-1939/results/SA1090_A96213A_museq.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,850 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_museq.vcf.gz that matches existing file
# 2019-11-04 18:42:50,850 - INFO - starting caching SC-1939/results/SA1090_A96213A_museq.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,917 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_museq.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:50,918 - INFO - starting caching SC-1939/results/SA1090_A96213A_museq.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:50,985 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_museq.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:50,986 - INFO - starting caching SC-1939/results/SA1090_A96213A_strelka_snv.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,050 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_strelka_snv.vcf.gz that matches existing file
# 2019-11-04 18:42:51,050 - INFO - starting caching SC-1939/results/SA1090_A96213A_strelka_snv.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,117 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_strelka_snv.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:51,118 - INFO - starting caching SC-1939/results/SA1090_A96213A_strelka_snv.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,185 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_strelka_snv.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:51,186 - INFO - starting caching SC-1939/results/SA1090_A96213A_strelka_indel.vcf.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,254 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_strelka_indel.vcf.gz that matches existing file
# 2019-11-04 18:42:51,255 - INFO - starting caching SC-1939/results/SA1090_A96213A_strelka_indel.vcf.gz.csi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,321 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_strelka_indel.vcf.gz.csi that matches existing file
# 2019-11-04 18:42:51,322 - INFO - starting caching SC-1939/results/SA1090_A96213A_strelka_indel.vcf.gz.tbi to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,388 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_strelka_indel.vcf.gz.tbi that matches existing file
# 2019-11-04 18:42:51,388 - INFO - starting caching SC-1939/results/haplotypes.tsv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,456 - INFO - skipping transfer of file resource SC-1939/results/haplotypes.tsv that matches existing file
# 2019-11-04 18:42:51,457 - INFO - starting caching SC-1939/results/SA921_A90554A_allele_counts.csv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,526 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_allele_counts.csv that matches existing file
# 2019-11-04 18:42:51,526 - INFO - starting caching SC-1939/results/SA922_A90554B_allele_counts.csv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,594 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_allele_counts.csv that matches existing file
# 2019-11-04 18:42:51,596 - INFO - starting caching SC-1939/results/SA1090_A96213A_allele_counts.csv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,774 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_allele_counts.csv that matches existing file
# 2019-11-04 18:42:51,775 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_allele_counts.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,843 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_allele_counts.csv.gz that matches existing file
# 2019-11-04 18:42:51,844 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_allele_counts.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,912 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_allele_counts.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:51,913 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_strelka.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:51,982 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_strelka.csv.gz that matches existing file
# 2019-11-04 18:42:51,984 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_strelka.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,053 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_strelka.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:52,054 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_cosmic_status.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,123 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_cosmic_status.csv.gz that matches existing file
# 2019-11-04 18:42:52,124 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_cosmic_status.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,193 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_cosmic_status.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:52,194 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_dbsnp_status.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,259 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_dbsnp_status.csv.gz that matches existing file
# 2019-11-04 18:42:52,260 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_dbsnp_status.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,325 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_dbsnp_status.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:52,326 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_mappability.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,394 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_mappability.csv.gz that matches existing file
# 2019-11-04 18:42:52,395 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_mappability.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,460 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_mappability.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:52,461 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_snpeff.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,529 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_snpeff.csv.gz that matches existing file
# 2019-11-04 18:42:52,530 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_snpeff.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,595 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_snpeff.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:52,596 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_trinuc.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,661 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_trinuc.csv.gz that matches existing file
# 2019-11-04 18:42:52,661 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_trinuc.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,727 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_trinuc.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:52,728 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_museq.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,794 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_museq.csv.gz that matches existing file
# 2019-11-04 18:42:52,794 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_museq.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,860 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_museq.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:52,860 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_union_counts.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,925 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_union_counts.csv.gz that matches existing file
# 2019-11-04 18:42:52,926 - INFO - starting caching SC-1939/results/SA921_A90554A_snv_union_counts.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:52,990 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_snv_union_counts.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:52,991 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_allele_counts.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,058 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_allele_counts.csv.gz that matches existing file
# 2019-11-04 18:42:53,059 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_allele_counts.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,125 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_allele_counts.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:53,126 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_strelka.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,192 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_strelka.csv.gz that matches existing file
# 2019-11-04 18:42:53,193 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_strelka.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,260 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_strelka.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:53,260 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_cosmic_status.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,328 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_cosmic_status.csv.gz that matches existing file
# 2019-11-04 18:42:53,329 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_cosmic_status.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,396 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_cosmic_status.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:53,396 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_dbsnp_status.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,464 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_dbsnp_status.csv.gz that matches existing file
# 2019-11-04 18:42:53,465 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_dbsnp_status.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,530 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_dbsnp_status.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:53,531 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_mappability.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,596 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_mappability.csv.gz that matches existing file
# 2019-11-04 18:42:53,597 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_mappability.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,662 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_mappability.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:53,663 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_snpeff.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,729 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_snpeff.csv.gz that matches existing file
# 2019-11-04 18:42:53,730 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_snpeff.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,796 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_snpeff.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:53,797 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_trinuc.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,863 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_trinuc.csv.gz that matches existing file
# 2019-11-04 18:42:53,864 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_trinuc.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,930 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_trinuc.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:53,930 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_museq.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:53,997 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_museq.csv.gz that matches existing file
# 2019-11-04 18:42:53,998 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_museq.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,063 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_museq.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:54,064 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_union_counts.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,131 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_union_counts.csv.gz that matches existing file
# 2019-11-04 18:42:54,132 - INFO - starting caching SC-1939/results/SA922_A90554B_snv_union_counts.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,198 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_snv_union_counts.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:54,199 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_allele_counts.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,268 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_allele_counts.csv.gz that matches existing file
# 2019-11-04 18:42:54,269 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_allele_counts.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,336 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_allele_counts.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:54,337 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_strelka.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,404 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_strelka.csv.gz that matches existing file
# 2019-11-04 18:42:54,405 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_strelka.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,495 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_strelka.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:54,495 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_cosmic_status.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,563 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_cosmic_status.csv.gz that matches existing file
# 2019-11-04 18:42:54,565 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_cosmic_status.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,632 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_cosmic_status.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:54,634 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_dbsnp_status.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,703 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_dbsnp_status.csv.gz that matches existing file
# 2019-11-04 18:42:54,704 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_dbsnp_status.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,774 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_dbsnp_status.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:54,775 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_mappability.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,844 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_mappability.csv.gz that matches existing file
# 2019-11-04 18:42:54,845 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_mappability.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,913 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_mappability.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:54,914 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_snpeff.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:54,983 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_snpeff.csv.gz that matches existing file
# 2019-11-04 18:42:54,984 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_snpeff.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,054 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_snpeff.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:55,055 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_trinuc.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,124 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_trinuc.csv.gz that matches existing file
# 2019-11-04 18:42:55,125 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_trinuc.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,194 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_trinuc.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:55,195 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_museq.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,269 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_museq.csv.gz that matches existing file
# 2019-11-04 18:42:55,270 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_museq.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,339 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_museq.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:55,340 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_union_counts.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,408 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_union_counts.csv.gz that matches existing file
# 2019-11-04 18:42:55,409 - INFO - starting caching SC-1939/results/SA1090_A96213A_snv_union_counts.csv.gz.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,476 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_snv_union_counts.csv.gz.yaml that matches existing file
# 2019-11-04 18:42:55,477 - INFO - starting caching SC-1939/results/SA921_A90554A_destruct.tsv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,546 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_destruct.tsv that matches existing file
# 2019-11-04 18:42:55,547 - INFO - starting caching SC-1939/results/SA921_A90554A_destruct_library.tsv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,615 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_destruct_library.tsv that matches existing file
# 2019-11-04 18:42:55,616 - INFO - starting caching SC-1939/results/SA921_A90554A_cell_counts_destruct.csv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,685 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_cell_counts_destruct.csv that matches existing file
# 2019-11-04 18:42:55,686 - INFO - starting caching SC-1939/results/SA922_A90554B_destruct.tsv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,755 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_destruct.tsv that matches existing file
# 2019-11-04 18:42:55,756 - INFO - starting caching SC-1939/results/SA922_A90554B_destruct_library.tsv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,825 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_destruct_library.tsv that matches existing file
# 2019-11-04 18:42:55,826 - INFO - starting caching SC-1939/results/SA922_A90554B_cell_counts_destruct.csv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,895 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_cell_counts_destruct.csv that matches existing file
# 2019-11-04 18:42:55,896 - INFO - starting caching SC-1939/results/SA1090_A96213A_destruct.tsv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:55,964 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_destruct.tsv that matches existing file
# 2019-11-04 18:42:55,965 - INFO - starting caching SC-1939/results/SA1090_A96213A_destruct_library.tsv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,034 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_destruct_library.tsv that matches existing file
# 2019-11-04 18:42:56,035 - INFO - starting caching SC-1939/results/SA1090_A96213A_cell_counts_destruct.csv to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,104 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_cell_counts_destruct.csv that matches existing file
# 2019-11-04 18:42:56,106 - INFO - starting caching SC-1939/results/manifest.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,174 - INFO - skipping transfer of file resource SC-1939/results/manifest.yaml that matches existing file
# 2019-11-04 18:42:56,175 - INFO - starting caching SC-1939/results/metadata.yaml to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,243 - INFO - skipping transfer of file resource SC-1939/results/metadata.yaml that matches existing file
# 2019-11-04 18:42:56,244 - INFO - starting caching SC-1939/results/SA1090_A96213A_cell_counts_destruct.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,312 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_cell_counts_destruct.csv.gz that matches existing file
# 2019-11-04 18:42:56,313 - INFO - starting caching SC-1939/results/SA1090_A96213A_destruct.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,381 - INFO - skipping transfer of file resource SC-1939/results/SA1090_A96213A_destruct.csv.gz that matches existing file
# 2019-11-04 18:42:56,381 - INFO - starting caching SC-1939/results/SA921_A90554A_cell_counts_destruct.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,446 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_cell_counts_destruct.csv.gz that matches existing file
# 2019-11-04 18:42:56,447 - INFO - starting caching SC-1939/results/SA921_A90554A_destruct.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,514 - INFO - skipping transfer of file resource SC-1939/results/SA921_A90554A_destruct.csv.gz that matches existing file
# 2019-11-04 18:42:56,514 - INFO - starting caching SC-1939/results/SA922_A90554B_cell_counts_destruct.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,579 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_cell_counts_destruct.csv.gz that matches existing file
# 2019-11-04 18:42:56,580 - INFO - starting caching SC-1939/results/SA922_A90554B_destruct.csv.gz to /Users/mcphera1/Scratch/tantalus_data/
# 2019-11-04 18:42:56,646 - INFO - skipping transfer of file resource SC-1939/results/SA922_A90554B_destruct.csv.gz that matches existing file

# %%
import scgenome.loaders.snv

LOGGING_FORMAT = "%(asctime)s - %(levelname)s - %(message)s"
logging.basicConfig(format=LOGGING_FORMAT, stream=sys.stderr, level=logging.INFO)

ticket_id = 'SC-1939'

local_cache_directory = os.environ['TANTALUS_CACHE_DIR']

ticket_directory = os.path.join(local_cache_directory, ticket_id)

snv_results = scgenome.loaders.snv.load_snv_data(
    ticket_directory,
)

print(snv_results.keys())
print(snv_results['snv_data'].head())
# Out:
# 2019-11-04 18:42:56,675 - INFO - starting load
# 2019-11-04 18:42:56,688 - INFO - Loading snv mappability annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_snv_mappability.csv.gz
# 2019-11-04 18:42:56,891 - INFO - Loading snv mappability annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_snv_mappability.csv.gz
# /Users/mcphera1/Projects/scgenome/scgenome/loaders/snv.py:274: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   strelka_filter=strelka_filter)
# 2019-11-04 18:42:57,119 - INFO - Loading snv mappability annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_snv_mappability.csv.gz
# 2019-11-04 18:42:58,016 - INFO - Loading snv strelka annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_snv_strelka.csv.gz
# 2019-11-04 18:42:58,053 - INFO - Loading snv strelka annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_snv_strelka.csv.gz
# 2019-11-04 18:42:58,089 - INFO - Loading snv strelka annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_snv_strelka.csv.gz
# 2019-11-04 18:42:58,308 - INFO - Loading snv museq annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_snv_museq.csv.gz
# /Users/mcphera1/Projects/scgenome/scgenome/loaders/snv.py:274: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   strelka_filter=strelka_filter)
# 2019-11-04 18:42:58,522 - INFO - Loading snv museq annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_snv_museq.csv.gz
# 2019-11-04 18:42:58,735 - INFO - Loading snv museq annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_snv_museq.csv.gz
# 2019-11-04 18:43:00,455 - INFO - Loading snv cosmic_status annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_snv_cosmic_status.csv.gz
# 2019-11-04 18:43:00,487 - INFO - Loading snv cosmic_status annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_snv_cosmic_status.csv.gz
# 2019-11-04 18:43:00,532 - INFO - Loading snv cosmic_status annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_snv_cosmic_status.csv.gz
# 2019-11-04 18:43:00,627 - INFO - cosmic table with shape (20078, 7), memory 924804
# 2019-11-04 18:43:00,676 - INFO - Loading snv snpeff annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_snv_snpeff.csv.gz
# 2019-11-04 18:43:04,522 - INFO - Loading snv snpeff annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_snv_snpeff.csv.gz
# 2019-11-04 18:43:08,199 - INFO - Loading snv snpeff annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_snv_snpeff.csv.gz
# 2019-11-04 18:43:21,627 - INFO - snpeff table with shape (533271, 8), memory 12546780
# 2019-11-04 18:43:21,674 - INFO - Loading snv trinuc annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_snv_trinuc.csv.gz
# 2019-11-04 18:43:21,820 - INFO - Loading snv trinuc annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_snv_trinuc.csv.gz
# 2019-11-04 18:43:21,959 - INFO - Loading snv trinuc annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_snv_trinuc.csv.gz
# 2019-11-04 18:43:22,562 - INFO - Loading snv allele_counts annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_snv_allele_counts.csv.gz
# 2019-11-04 18:43:45,836 - INFO - Loading snv allele_counts annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_snv_allele_counts.csv.gz
# 2019-11-04 18:44:11,021 - INFO - Loading snv allele_counts annotations from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_snv_allele_counts.csv.gz
# 2019-11-04 18:46:05,467 - INFO - initial snv table with shape (75750749, 7), memory 3030128824
# 2019-11-04 18:46:05,478 - INFO - summing snv counts
# 2019-11-04 18:50:20,676 - INFO - total snv count 527431
# 2019-11-04 18:50:20,681 - INFO - snv table with shape (528130, 6), memory 14260806
# 2019-11-04 18:50:20,905 - INFO - post mappability with snv count 121116
# 2019-11-04 18:50:20,908 - INFO - snv table with shape (125034, 7), memory 6252084
# 2019-11-04 18:50:20,987 - INFO - post cosmic with snv count 121116
# 2019-11-04 18:50:20,989 - INFO - snv table with shape (125034, 8), memory 7252356
# 2019-11-04 18:50:21,298 - INFO - post snpeff with snv count 121116
# 2019-11-04 18:50:21,300 - INFO - snv table with shape (125034, 12), memory 10257070
# 2019-11-04 18:50:21,547 - INFO - snv table with shape (125034, 13), memory 11257342
# 2019-11-04 18:50:21,694 - INFO - post strelka with snv count 121116
# 2019-11-04 18:50:21,696 - INFO - snv table with shape (125034, 14), memory 14132740
# 2019-11-04 18:50:22,045 - INFO - post museq with snv count 121116
# 2019-11-04 18:50:22,048 - INFO - snv table with shape (135827, 15), memory 16277070
# 2019-11-04 18:50:22,060 - INFO - post museq filter with snv count 16983
# 2019-11-04 18:50:22,063 - INFO - snv table with shape (18803, 15), memory 3872526
# 2019-11-04 18:50:22,073 - INFO - post strelka filter with snv count 14068
# 2019-11-04 18:50:22,076 - INFO - snv table with shape (15376, 15), memory 3509264
# 2019-11-04 18:50:22,083 - INFO - finishing load with snv count 14068
# 2019-11-04 18:50:22,085 - INFO - snv table with shape (15376, 15), memory 3509264
# 2019-11-04 18:50:22,297 - INFO - final snv table with shape (15376, 15), memory 3083016
# 2019-11-04 18:50:22,338 - INFO - Loading snv counts from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_snv_union_counts.csv.gz
# /Users/mcphera1/Projects/scgenome/venv/lib/python3.7/site-packages/ipykernel_launcher.py:14: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2019-11-04 18:51:05,751 - INFO - Loaded snv counts table with shape (43825168, 7), memory 1402432992
# 2019-11-04 18:51:21,602 - INFO - Filtered snv counts table to shape (1248626, 7), memory 49972576
# 2019-11-04 18:51:21,603 - INFO - Loading snv counts from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_snv_union_counts.csv.gz
# 2019-11-04 18:52:07,815 - INFO - Loaded snv counts table with shape (44506208, 7), memory 1424226016
# 2019-11-04 18:52:23,664 - INFO - Filtered snv counts table to shape (1295393, 7), memory 51843000
# 2019-11-04 18:52:23,665 - INFO - Loading snv counts from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_snv_union_counts.csv.gz
# 2019-11-04 18:53:09,989 - INFO - Loaded snv counts table with shape (46669168, 7), memory 1493441088
# 2019-11-04 18:53:26,580 - INFO - Filtered snv counts table to shape (1240690, 7), memory 49655232
# 2019-11-04 18:53:27,205 - INFO - Loaded all snv counts tables with shape (3784709, 7), memory 121209440
# dict_keys(['snv_data', 'snv_count_data'])
#    chrom    coord ref alt  alt_counts_sum  ref_counts_sum  mappability  \
# 17     1   985349   G   A            32.0            27.0          1.0
# 24     1  1079129   G   T            80.0             0.0          1.0
# 66     1  2032634   T   C            65.0            62.0          1.0
# 68     1  2063033   C   A           354.0             1.0          1.0
# 74     1  2117392   G   A           430.0             2.0          1.0
#
#    is_cosmic gene_name effect effect_impact amino_acid_change  \
# 17      True       NaN    NaN           NaN               NaN
# 24       NaN       NaN    NaN           NaN               NaN
# 66       NaN       NaN    NaN           NaN               NaN
# 68       NaN       NaN    NaN           NaN               NaN
# 74       NaN       NaN    NaN           NaN               NaN
#
#    tri_nucleotide_context  max_strelka_score  max_museq_score
# 17                    CGT                 93             0.99
# 24                    TGC                316             1.00
# 66                    NaN                124             0.95
# 68                    ACA                479             0.99
# 74                    CGG                433             0.99

# %%
import scgenome.loaders.breakpoint

LOGGING_FORMAT = "%(asctime)s - %(levelname)s - %(message)s"
logging.basicConfig(format=LOGGING_FORMAT, stream=sys.stderr, level=logging.INFO)

ticket_id = 'SC-1939'

local_cache_directory = os.environ['TANTALUS_CACHE_DIR']

ticket_directory = os.path.join(local_cache_directory, ticket_id)

breakpoint_results = scgenome.loaders.breakpoint.load_breakpoint_data(
    ticket_directory,
)

print(breakpoint_results.keys())
print(breakpoint_results['breakpoint_data'].head())
print(breakpoint_results['breakpoint_count_data'].head())
# Out:
# dict_keys(['breakpoint_data', 'breakpoint_count_data'])
#    prediction_id chromosome_1 strand_1  position_1 chromosome_2 strand_2  \
# 0            456            1        -    17084897            1        -
# 1            569            1        -   234914910            1        -
# 2           1032            1        -   148902774            1        -
# 3           1313            1        -   204051209            1        -
# 4           2081            1        -    64520958            1        -
#
#    position_2  homology  num_split inserted  ...  dgv_ids  is_germline  \
# 0    17084866         8          3      nan  ...      NaN        False
# 1   234914883        13          6      nan  ...      NaN        False
# 2   148902756         6          2      nan  ...      NaN        False
# 3   204051202         0          2      nan  ...      NaN        False
# 4    64520949         3          2      nan  ...      NaN        False
#
#    is_dgv  num_patients  is_filtered  dist_filtered  balanced  \
# 0   False             1        False         2769.0     False
# 1   False             1        False         2695.0     False
# 2   False             1        False         3302.0     False
# 3   False             1        False        15009.0     False
# 4   False             1        False        28133.0     False
#
#    rearrangement_type library_id  sample_id
# 0            foldback    A90554A      SA921
# 1            foldback    A90554A      SA921
# 2            foldback    A90554A      SA921
# 3            foldback    A90554A      SA921
# 4            foldback    A90554A      SA921
#
# [5 rows x 37 columns]
#     prediction_id                cell_id  read_count library_id sample_id
# 1               0  SA921-A90554A-R10-C22           1    A90554A     SA921
# 34              1  SA921-A90554A-R03-C08           1    A90554A     SA921
# 35              1  SA921-A90554A-R03-C19           1    A90554A     SA921
# 36              1  SA921-A90554A-R03-C27           1    A90554A     SA921
# 37              1  SA921-A90554A-R03-C36           1    A90554A     SA921

# %%
import scgenome.loaders.allele

LOGGING_FORMAT = "%(asctime)s - %(levelname)s - %(message)s"
logging.basicConfig(format=LOGGING_FORMAT, stream=sys.stderr, level=logging.INFO)

ticket_id = 'SC-1939'

local_cache_directory = '/Users/mcphera1/Scratch/tantalus_data/'

ticket_directory = os.path.join(local_cache_directory, ticket_id)

allele_results = scgenome.loaders.allele.load_haplotype_allele_data(
    ticket_directory,
)

print(allele_results.keys())
print(allele_results['allele_counts'].head())
# Out:
# 2019-11-04 18:53:33,567 - INFO - Loading haplotype allele counts from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA921_A90554A_allele_counts.csv
# 2019-11-04 18:54:00,981 - INFO - Loaded haplotype allele counts table with shape (29543456, 7), memory 1418112296
# 2019-11-04 18:54:00,982 - INFO - Loading haplotype allele counts from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA922_A90554B_allele_counts.csv
# 2019-11-04 18:54:26,368 - INFO - Loaded haplotype allele counts table with shape (27822447, 7), memory 1335503608
# 2019-11-04 18:54:26,369 - INFO - Loading haplotype allele counts from /Users/mcphera1/Scratch/tantalus_data/SC-1939/results/SA1090_A96213A_allele_counts.csv
# 2019-11-04 18:55:01,056 - INFO - Loaded haplotype allele counts table with shape (34468856, 7), memory 1654532408
# 2019-11-04 18:55:15,163 - INFO - Loaded all haplotype allele counts table with shape (91834759, 7), memory 4408166984
# dict_keys(['allele_counts'])
#    allele_id                cell_id chromosome      end  hap_label  readcount  \
# 0          0  SA921-A90554A-R12-C09          1  1000000         27          1
# 1          0  SA921-A90554A-R12-C09          1  2500000        151          1
# 2          1  SA921-A90554A-R12-C09          1  3845268        259          1
# 3          0  SA921-A90554A-R12-C09          1  4500000        285          1
# 4          0  SA921-A90554A-R12-C09          1  7000000        406          1
#
#      start
# 0   521368
# 1  2000000
# 2  3500000
# 3  4000000
# 4  6500000
